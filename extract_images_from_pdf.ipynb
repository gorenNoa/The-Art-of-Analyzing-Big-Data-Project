# %%
# !pip install pdf2image
# Out:
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from pdf2image) (11.3.0)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.17.0

# %%
# !apt-get install -y poppler-utils
# !which pdftoppm
# !ls -la /usr/bin/pdftoppm
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.9 [186 kB]
# Fetched 186 kB in 1s (269 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 126380 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.9_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.9) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.9) ...
# Processing triggers for man-db (2.10.2-1) ...
# /usr/bin/pdftoppm
# -rwxr-xr-x 1 root root 35240 Jul 25 15:21 /usr/bin/pdftoppm

# %%
import os
import cv2
import numpy as np
from pdf2image import convert_from_path
from PIL import Image
import re
from pathlib import Path
import shutil
from typing import List, Tuple

# %%
PDF_PATH = "/content/drive/MyDrive/Miki_class/Project/Catalog/PDFs"
IMAGES_PATH = "/content/drive/MyDrive/Miki_class/Project/Catalog/images"

# %%
# PDF conversion settings
PDF_DPI = 200  # High quality for OCR and detection
IMAGE_FORMAT = "jpg"  # Consistent format
IMAGE_QUALITY = 95  # High quality JPEG

# %%
def convert_pdf_to_images(pdf_path: str, issue_number: str) -> Tuple[bool, int]:

    # Create issue folder
    issue_folder = os.path.join(IMAGES_PATH, issue_number)
    os.makedirs(issue_folder, exist_ok=True)

    try:
        print(f"   Converting PDF to images...")

        # Convert PDF to images
        pages = convert_from_path(pdf_path, dpi=PDF_DPI)

        if not pages:
            print(f"   No pages found in PDF")
            return False, 0

        print(f"   Processing {len(pages)} pages...")

        # Save each page
        saved_pages = 0
        for i, page in enumerate(pages):
            page_number = i + 1
            filename = f"page_{page_number:02d}.jpg"
            page_path = os.path.join(issue_folder, filename)

            # Save with high quality
            page.save(page_path)
            saved_pages += 1

            if (i + 1) % 5 == 0:  # Progress update every 5 pages
                print(f"      Saved {i + 1}/{len(pages)} pages...")

        print(f"   Successfully saved {saved_pages} pages to Issue {issue_number}")
        return True, saved_pages

    except Exception as e:
        print(f"   Error converting PDF: {str(e)}")
        return False, 0

# %%
if not os.path.exists(PDF_PATH):
    print(f"PDF directory not found: {PDF_PATH}")
    exit()

pdf_files = [f for f in os.listdir(PDF_PATH) if f.endswith('.pdf')]

if not pdf_files:
    print(f"No PDF files found in: {PDF_PATH}")
    exit()

print(f"Found {len(pdf_files)} PDF files to convert")
print()
# Out:
# Found 18 PDF files to convert

# %%
total_converted = 0
total_pages = 0
successful_conversions = []
failed_conversions = []

# Convert each PDF
for i, pdf_file in enumerate(pdf_files, 1):
    # Extract issue number from filename (remove .pdf extension)
    issue_number = os.path.splitext(pdf_file)[0]
    pdf_path = os.path.join(PDF_PATH, pdf_file)

    print(f"[{i}/{len(pdf_files)}] Converting: {pdf_file}")
    print(f"   Target: Issue {issue_number}")

    # Convert PDF
    success, pages_converted = convert_pdf_to_images(pdf_path, issue_number)

    if success:
        successful_conversions.append({
            'pdf_file': pdf_file,
            'issue_number': issue_number,
            'pages': pages_converted
        })
        total_converted += 1
        total_pages += pages_converted
        print(f"   Success: {pages_converted} pages converted")
    else:
        failed_conversions.append({
            'pdf_file': pdf_file,
            'issue_number': issue_number,
            'error': 'Conversion failed'
        })
        print(f"   Failed to convert")

    print()
# Out:
# [1/18] Converting: 1193.pdf
#    Target: Issue 1193
#    Converting PDF to images...
#    Processing 208 pages...
#       Saved 5/208 pages...
#       Saved 10/208 pages...
#       Saved 15/208 pages...
#       Saved 20/208 pages...
#       Saved 25/208 pages...
#       Saved 30/208 pages...
#       Saved 35/208 pages...
#       Saved 40/208 pages...
#       Saved 45/208 pages...
#       Saved 50/208 pages...
#       Saved 55/208 pages...
#       Saved 60/208 pages...
#       Saved 65/208 pages...
#       Saved 70/208 pages...
#       Saved 75/208 pages...
#       Saved 80/208 pages...
#       Saved 85/208 pages...
#       Saved 90/208 pages...
#       Saved 95/208 pages...
#       Saved 100/208 pages...
#       Saved 105/208 pages...
#       Saved 110/208 pages...
#       Saved 115/208 pages...
#       Saved 120/208 pages...
#       Saved 125/208 pages...
#       Saved 130/208 pages...
#       Saved 135/208 pages...
#       Saved 140/208 pages...
#       Saved 145/208 pages...
#       Saved 150/208 pages...
#       Saved 155/208 pages...
#       Saved 160/208 pages...
#       Saved 165/208 pages...
#       Saved 170/208 pages...
#       Saved 175/208 pages...
#       Saved 180/208 pages...
#       Saved 185/208 pages...
#       Saved 190/208 pages...
#       Saved 195/208 pages...
#       Saved 200/208 pages...
#       Saved 205/208 pages...
#    Successfully saved 208 pages to Issue 1193
#    Success: 208 pages converted
#
# [2/18] Converting: 1194.pdf
#    Target: Issue 1194
#    Converting PDF to images...
#    Processing 192 pages...
#       Saved 5/192 pages...
#       Saved 10/192 pages...
#       Saved 15/192 pages...
#       Saved 20/192 pages...
#       Saved 25/192 pages...
#       Saved 30/192 pages...
#       Saved 35/192 pages...
#       Saved 40/192 pages...
#       Saved 45/192 pages...
#       Saved 50/192 pages...
#       Saved 55/192 pages...
#       Saved 60/192 pages...
#       Saved 65/192 pages...
#       Saved 70/192 pages...
#       Saved 75/192 pages...
#       Saved 80/192 pages...
#       Saved 85/192 pages...
#       Saved 90/192 pages...
#       Saved 95/192 pages...
#       Saved 100/192 pages...
#       Saved 105/192 pages...
#       Saved 110/192 pages...
#       Saved 115/192 pages...
#       Saved 120/192 pages...
#       Saved 125/192 pages...
#       Saved 130/192 pages...
#       Saved 135/192 pages...
#       Saved 140/192 pages...
#       Saved 145/192 pages...
#       Saved 150/192 pages...
#       Saved 155/192 pages...
#       Saved 160/192 pages...
#       Saved 165/192 pages...
#       Saved 170/192 pages...
#       Saved 175/192 pages...
#       Saved 180/192 pages...
#       Saved 185/192 pages...
#       Saved 190/192 pages...
#    Successfully saved 192 pages to Issue 1194
#    Success: 192 pages converted
#
# [3/18] Converting: 1196.pdf
#    Target: Issue 1196
#    Converting PDF to images...
#    Processing 192 pages...
#       Saved 5/192 pages...
#       Saved 10/192 pages...
#       Saved 15/192 pages...
#       Saved 20/192 pages...
#       Saved 25/192 pages...
#       Saved 30/192 pages...
#       Saved 35/192 pages...
#       Saved 40/192 pages...
#       Saved 45/192 pages...
#       Saved 50/192 pages...
#       Saved 55/192 pages...
#       Saved 60/192 pages...
#       Saved 65/192 pages...
#       Saved 70/192 pages...
#       Saved 75/192 pages...
#       Saved 80/192 pages...
#       Saved 85/192 pages...
#       Saved 90/192 pages...
#       Saved 95/192 pages...
#       Saved 80/192 pages...
#       Saved 85/192 pages...
#       Saved 90/192 pages...
#       Saved 95/192 pages...
#       Saved 100/192 pages...
#       Saved 105/192 pages...
#       Saved 110/192 pages...
#       Saved 115/192 pages...
#       Saved 120/192 pages...
#       Saved 125/192 pages...
#       Saved 130/192 pages...
#       Saved 135/192 pages...
#       Saved 140/192 pages...
#       Saved 145/192 pages...
#       Saved 150/192 pages...
#       Saved 155/192 pages...
#       Saved 160/192 pages...
#       Saved 165/192 pages...
#       Saved 170/192 pages...
#       Saved 175/192 pages...
#       Saved 180/192 pages...
#       Saved 185/192 pages...
#       Saved 190/192 pages...
#    Successfully saved 192 pages to Issue 1201
#    Success: 192 pages converted
#
# [9/18] Converting: 1203.pdf
#    Target: Issue 1203
#    Converting PDF to images...
#    Processing 168 pages...
#       Saved 5/168 pages...
#       Saved 10/168 pages...
#       Saved 15/168 pages...
#       Saved 20/168 pages...
#       Saved 25/168 pages...
#       Saved 30/168 pages...
#       Saved 35/168 pages...
#       Saved 40/168 pages...
#       Saved 45/168 pages...
#       Saved 50/168 pages...
#       Saved 55/168 pages...
#       Saved 60/168 pages...
#       Saved 65/168 pages...
#       Saved 70/168 pages...
#       Saved 75/168 pages...
#       Saved 80/168 pages...
#       Saved 85/168 pages...
#       Saved 90/168 pages...
#       Saved 95/168 pages...
#       Saved 100/168 pages...
#       Saved 105/168 pages...
#       Saved 110/168 pages...
#       Saved 115/168 pages...
#       Saved 120/168 pages...
#       Saved 125/168 pages...
#       Saved 130/168 pages...
#       Saved 135/168 pages...
#       Saved 140/168 pages...
#       Saved 145/168 pages...
#       Saved 150/168 pages...
#       Saved 155/168 pages...
#       Saved 160/168 pages...
#       Saved 165/168 pages...
#    Successfully saved 168 pages to Issue 1203
#    Success: 168 pages converted
#
# [10/18] Converting: 1202.pdf
#    Target: Issue 1202
#    Converting PDF to images...
#    Processing 143 pages...
#       Saved 5/143 pages...
#       Saved 10/143 pages...
#       Saved 15/143 pages...
#       Saved 20/143 pages...
#       Saved 25/143 pages...
#       Saved 30/143 pages...
#       Saved 35/143 pages...
#       Saved 40/143 pages...
#       Saved 45/143 pages...
#       Saved 50/143 pages...
#       Saved 55/143 pages...
#       Saved 60/143 pages...
#       Saved 65/143 pages...
#       Saved 70/143 pages...
#       Saved 75/143 pages...
#       Saved 80/143 pages...
#       Saved 85/143 pages...
#       Saved 90/143 pages...
#       Saved 95/143 pages...
#       Saved 100/143 pages...
#       Saved 105/143 pages...
#       Saved 110/143 pages...
#       Saved 115/143 pages...
#       Saved 120/143 pages...
#       Saved 125/143 pages...
#       Saved 130/143 pages...
#       Saved 135/143 pages...
#       Saved 140/143 pages...
#    Successfully saved 143 pages to Issue 1202
#    Success: 143 pages converted
#
# [11/18] Converting: 1204.pdf
#    Target: Issue 1204
#    Converting PDF to images...
#    Processing 184 pages...
#       Saved 5/184 pages...
#       Saved 10/184 pages...
#       Saved 15/184 pages...
#       Saved 20/184 pages...
#       Saved 25/184 pages...
#       Saved 30/184 pages...
#       Saved 35/184 pages...
#       Saved 40/184 pages...
#    Success: 176 pages converted
#
# [14/18] Converting: 12155.pdf
#    Target: Issue 12155
#    Converting PDF to images...
#    Processing 232 pages...
#       Saved 5/232 pages...
#       Saved 10/232 pages...
#       Saved 15/232 pages...
#       Saved 20/232 pages...
#       Saved 25/232 pages...
#       Saved 30/232 pages...
#       Saved 35/232 pages...
#       Saved 40/232 pages...
#       Saved 45/232 pages...
#       Saved 50/232 pages...
#       Saved 55/232 pages...
#       Saved 60/232 pages...
#       Saved 65/232 pages...
#       Saved 70/232 pages...
#       Saved 75/232 pages...
#       Saved 80/232 pages...
#       Saved 85/232 pages...
#       Saved 90/232 pages...
#       Saved 95/232 pages...
#       Saved 100/232 pages...
#       Saved 105/232 pages...
#       Saved 110/232 pages...
#       Saved 115/232 pages...
#       Saved 120/232 pages...
#       Saved 125/232 pages...
#       Saved 130/232 pages...
#       Saved 135/232 pages...
#       Saved 140/232 pages...
#       Saved 145/232 pages...
#       Saved 150/232 pages...
#       Saved 155/232 pages...
#       Saved 160/232 pages...
#       Saved 165/232 pages...
#       Saved 170/232 pages...
#       Saved 175/232 pages...
#       Saved 180/232 pages...
#       Saved 185/232 pages...
#       Saved 190/232 pages...
#       Saved 195/232 pages...
#       Saved 200/232 pages...
#       Saved 205/232 pages...
#       Saved 210/232 pages...
#       Saved 215/232 pages...
#       Saved 220/232 pages...
#       Saved 225/232 pages...
#       Saved 230/232 pages...
#    Successfully saved 232 pages to Issue 12155
#    Success: 232 pages converted
#
# [15/18] Converting: 12155b.pdf
#    Target: Issue 12155b
#    Converting PDF to images...
#    Processing 32 pages...
#       Saved 5/32 pages...
#       Saved 10/32 pages...
#       Saved 15/32 pages...
#       Saved 20/32 pages...
#       Saved 25/32 pages...
#       Saved 30/32 pages...
#    Successfully saved 32 pages to Issue 12155b
#    Success: 32 pages converted
#
# [16/18] Converting: 1229.pdf
#    Target: Issue 1229
#    Converting PDF to images...
#    Processing 160 pages...
#       Saved 5/160 pages...
#       Saved 10/160 pages...
#       Saved 15/160 pages...
#       Saved 20/160 pages...
#       Saved 25/160 pages...
#       Saved 30/160 pages...
#       Saved 35/160 pages...
#       Saved 40/160 pages...
#       Saved 45/160 pages...
#       Saved 50/160 pages...
#       Saved 55/160 pages...
#       Saved 60/160 pages...
#       Saved 65/160 pages...
#       Saved 70/160 pages...
#       Saved 75/160 pages...
#       Saved 80/160 pages...
#       Saved 85/160 pages...
#       Saved 90/160 pages...
#       Saved 95/160 pages...
#       Saved 100/160 pages...
#       Saved 105/160 pages...
#       Saved 110/160 pages...
#       Saved 115/160 pages...
#       Saved 120/160 pages...
#       Saved 125/160 pages...
#       Saved 130/160 pages...
#       Saved 135/160 pages...
#       Saved 140/160 pages...
#       Saved 145/160 pages...
#       Saved 150/160 pages...
#       Saved 155/160 pages...
#       Saved 160/160 pages...
#    Successfully saved 160 pages to Issue 1229
#    Success: 160 pages converted
#
# [17/18] Converting: 1230.pdf
#    Target: Issue 1230
#    Converting PDF to images...
#    Processing 208 pages...
#       Saved 5/208 pages...
#       Saved 10/208 pages...
#       Saved 15/208 pages...
#       Saved 20/208 pages...
#       Saved 25/208 pages...
#       Saved 30/208 pages...
#       Saved 35/208 pages...
#       Saved 40/208 pages...
#       Saved 45/208 pages...
#       Saved 50/208 pages...
#       Saved 55/208 pages...
#       Saved 60/208 pages...
#       Saved 65/208 pages...
#       Saved 70/208 pages...
#       Saved 75/208 pages...
#       Saved 80/208 pages...
#       Saved 85/208 pages...
#       Saved 90/208 pages...
#       Saved 95/208 pages...
#       Saved 100/208 pages...
#       Saved 105/208 pages...
#       Saved 110/208 pages...
#       Saved 115/208 pages...
#       Saved 120/208 pages...
#       Saved 125/208 pages...
#       Saved 130/208 pages...
#       Saved 135/208 pages...
#       Saved 140/208 pages...
#       Saved 145/208 pages...
#       Saved 150/208 pages...
#       Saved 155/208 pages...
#       Saved 160/208 pages...
#       Saved 165/208 pages...
#       Saved 170/208 pages...
#       Saved 175/208 pages...
#       Saved 180/208 pages...
#       Saved 185/208 pages...
#       Saved 190/208 pages...
#       Saved 195/208 pages...
#       Saved 200/208 pages...
#       Saved 205/208 pages...
#    Successfully saved 208 pages to Issue 1230
#    Success: 208 pages converted
#
# [18/18] Converting: 1231.pdf
#    Target: Issue 1231
#    Converting PDF to images...
#    Processing 176 pages...
#       Saved 5/176 pages...
#       Saved 10/176 pages...
#       Saved 15/176 pages...
#       Saved 20/176 pages...
#       Saved 25/176 pages...
#       Saved 30/176 pages...
#       Saved 35/176 pages...
#       Saved 40/176 pages...
#       Saved 45/176 pages...
#       Saved 50/176 pages...
#       Saved 55/176 pages...
#       Saved 60/176 pages...
#       Saved 65/176 pages...
#       Saved 70/176 pages...
#       Saved 75/176 pages...
#       Saved 80/176 pages...
#       Saved 85/176 pages...
#       Saved 90/176 pages...
#       Saved 95/176 pages...
#       Saved 100/176 pages...
#       Saved 105/176 pages...
#       Saved 110/176 pages...
#       Saved 115/176 pages...
#       Saved 120/176 pages...
#       Saved 125/176 pages...
#       Saved 130/176 pages...
#       Saved 135/176 pages...
#       Saved 140/176 pages...
#       Saved 145/176 pages...
#       Saved 150/176 pages...
#       Saved 155/176 pages...
#       Saved 160/176 pages...
#       Saved 165/176 pages...
#       Saved 170/176 pages...
#       Saved 175/176 pages...
#    Successfully saved 176 pages to Issue 1231
#    Success: 176 pages converted

# %%
if os.path.exists(IMAGES_PATH):
    all_issue_folders = [f for f in os.listdir(IMAGES_PATH)
                        if os.path.isdir(os.path.join(IMAGES_PATH, f))]

    print(f"Total issue folders: {len(all_issue_folders)}")

    # Count total images
    total_images = 0
    for folder in all_issue_folders:
        folder_path = os.path.join(IMAGES_PATH, folder)
        image_files = [f for f in os.listdir(folder_path)
                      if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
        total_images += len(image_files)

    print(f"Total images across all issues: {total_images}")

    print(f"\nCONVERSION COMPLETE!")
    print(f"   All PDFs converted to high-quality images")
    print(f"   Images saved to: {IMAGES_PATH}")

else:
    print("Images directory not found after conversion")
# Out:
# Total issue folders: 31
# Total images across all issues: 5435
#
# CONVERSION COMPLETE!
#    All PDFs converted to high-quality images
#    Images saved to: /content/drive/MyDrive/Miki_class/Project/Catalog/images
