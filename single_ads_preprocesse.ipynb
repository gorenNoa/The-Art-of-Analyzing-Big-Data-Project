# %%
# !pip install pytesseract
# !apt-get install tesseract-ocr tesseract-ocr-heb poppler-utils
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from pytesseract) (25.0)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from pytesseract) (11.3.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# The following NEW packages will be installed:
#   poppler-utils tesseract-ocr-heb
# 0 upgraded, 2 newly installed, 0 to remove and 35 not upgraded.
# Need to get 618 kB of archives.
# After this operation, 1,673 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.10 [186 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-heb all 1:4.00~git30-7274cfa-1.1 [432 kB]
# Fetched 618 kB in 0s (2,728 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 126371 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.10_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.10) ...
# Selecting previously unselected package tesseract-ocr-heb.
# Preparing to unpack .../tesseract-ocr-heb_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-heb (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-heb (1:4.00~git30-7274cfa-1.1) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.10) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
import subprocess
import sys

def install_hebrew_ocr():
    """Install Hebrew language pack for tesseract"""
    try:
        print("📦 Installing Hebrew OCR support...")

        # Install Hebrew language pack
        result = subprocess.run(['apt-get', 'update'], capture_output=True, text=True)
        result = subprocess.run(['apt-get', 'install', '-y', 'tesseract-ocr-heb'], capture_output=True, text=True)

        if result.returncode == 0:
            print("✅ Hebrew language pack installed successfully!")

            # Test Hebrew support
            import pytesseract
            langs = pytesseract.get_languages()
            if 'heb' in langs:
                print("✅ Hebrew (heb) language confirmed available")
                print(f"📋 Available languages: {sorted(langs)}")
                return True
            else:
                print("⚠️ Hebrew not found in available languages")
                print(f"📋 Available languages: {sorted(langs)}")
                return False
        else:
            print(f"❌ Installation failed: {result.stderr}")
            return False

    except Exception as e:
        print(f"❌ Error installing Hebrew support: {e}")
        return False

# Install Hebrew support
hebrew_installed = install_hebrew_ocr()
# Out:
# 📦 Installing Hebrew OCR support...
# ✅ Hebrew language pack installed successfully!
# ✅ Hebrew (heb) language confirmed available
# 📋 Available languages: ['eng', 'heb', 'osd']

# %%
import cv2
import numpy as np
import os
from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image
import json
from typing import List, Dict, Tuple
import pytesseract
import re

pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'

# %%
BASE_PATH = "/content/drive/MyDrive/Miki_class/Project/Catalog"
SINGLE_AD_INPUT = os.path.join(BASE_PATH, "classified_images", "single_ads")
SINGLE_AD_OUTPUT = os.path.join(BASE_PATH, "processed_ads", "single_ads")

# %%
# Processing parameters
CROP_MARGINS = True     # Whether to crop newspaper margins/headers
TOP_MARGIN = 50         # Pixels to crop from top (for headers)
AUTO_DETECT_FOOTER = True  # Automatically detect and remove footers
FOOTER_SCAN_HEIGHT = 180   # Height from bottom to scan for footer (pixels)
MANUAL_BOTTOM_MARGIN = 30  # Fallback bottom margin if no footer detected
LEFT_MARGIN = 20        # Pixels to crop from left
RIGHT_MARGIN = 20       # Pixels to crop from right

# Footer detection parameters
FOOTER_TEXT_PATTERNS = [
    "כח הפרסום",           # Main footer text
    r"הפרסום\s+\d+",       # "הפרסום" + space + any numbers
    r"כח הפרסום\s+\d+",    # "כח הפרסום" + space + any numbers
    r"\d+\s+הפרסום",       # Numbers + space + "הפרסום" (reverse order)
    "הפרסום",
]

# Multiple OCR strategies
OCR_STRATEGIES = [
    ("Hebrew + English", r'--oem 3 --psm 6 -l heb+eng'),
    ("Hebrew only", r'--oem 3 --psm 6 -l heb'),
    ("Single text line Hebrew", r'--oem 3 --psm 7 -l heb'),
    ("Single word Hebrew", r'--oem 3 --psm 8 -l heb'),
    ("Sparse text Hebrew", r'--oem 3 --psm 11 -l heb'),
] if hebrew_installed else [
    ("English fallback", r'--oem 3 --psm 6 -l eng'),
    ("Auto detect", r'--oem 3 --psm 6'),
]

# Quality settings
MIN_IMAGE_SIZE = (200, 200)  # Minimum size for output ads
JPEG_QUALITY = 90           # Output quality (1-100)

# %%
def extract_page_number(filename: str) -> int:
    try:
        # Remove extension
        name_without_ext = os.path.splitext(filename)[0]

        if name_without_ext.startswith('page_'):
            # Format: page_05.jpg
            return int(name_without_ext.split('_')[1])
        else:
            # Format: 5.jpg
            return int(name_without_ext)
    except:
        return 0  # Return 0 if can't parse

# %%
def get_single_ad_images(input_base_path: str) -> List[Dict]:
    """Get all images from single_ad_pages folders"""
    image_extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.tiff'}
    all_images = []

    if not os.path.exists(input_base_path):
        print(f"❌ Input path does not exist: {input_base_path}")
        return []

    # Go through each issue folder
    for issue_folder in os.listdir(input_base_path):
        issue_path = os.path.join(input_base_path, issue_folder)

        if not os.path.isdir(issue_path):
            continue

        print(f"📁 Found issue folder: {issue_folder}")

        # Get all image files in this issue
        issue_images = []
        for filename in os.listdir(issue_path):
            if any(filename.lower().endswith(ext) for ext in image_extensions):
                page_num = extract_page_number(filename)
                if page_num > 0:  # Only include files we can parse
                    image_info = {
                        'issue': issue_folder,
                        'page_num': page_num,
                        'filename': filename,
                        'full_path': os.path.join(issue_path, filename)
                    }
                    issue_images.append(image_info)

        # Sort by page number
        issue_images.sort(key=lambda x: x['page_num'])
        all_images.extend(issue_images)

        print(f"  ✓ Found {len(issue_images)} images")
        for img in issue_images:
            print(f"    - Page {img['page_num']}: {img['filename']}")

    return all_images

# %%
def try_visual_detection(footer_region: np.ndarray, scan_height: int) -> Tuple[bool, int]:
    """More conservative visual footer detection"""

    gray = cv2.cvtColor(footer_region, cv2.COLOR_BGR2GRAY)
    height, width = gray.shape

    # Look for text regions in BOTTOM portion only (last 30% of scan region)
    bottom_region = gray[int(height * 0.7):, :]

    # Threshold to find dark text on light background
    _, thresh = cv2.threshold(bottom_region, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Count dark pixels (potential text)
    dark_pixel_ratio = np.sum(thresh == 255) / (bottom_region.shape[0] * bottom_region.shape[1])

    # More conservative thresholds to reduce false positives
    if 0.01 < dark_pixel_ratio < 0.15:  # Between 1% and 15% dark pixels
        # Look for horizontal text patterns
        horizontal_projection = np.sum(thresh, axis=1)
        text_lines = np.where(horizontal_projection > width * 0.1)[0]  # Lines with significant text

        if len(text_lines) > 0:
            print(f"  👁️ Visual detection: Found text patterns (dark ratio: {dark_pixel_ratio:.3f})")
            # Crop from where text starts, plus padding
            first_text_line = text_lines[0]
            crop_from_bottom = height - int(height * 0.7) - first_text_line + 20
            return True, max(40, min(crop_from_bottom, scan_height // 2))

    print(f"  👁️ Visual detection: No footer pattern (dark ratio: {dark_pixel_ratio:.3f})")
    return False, 0

# %%
def has_footer_characteristics(footer_region: np.ndarray) -> bool:
    """Check if region has footer-like characteristics"""

    gray = cv2.cvtColor(footer_region, cv2.COLOR_BGR2GRAY)
    height, width = gray.shape

    # Check for consistent background in top portion
    top_portion = gray[:height//3, :]
    top_std = np.std(top_portion)

    # Check for text-like patterns in bottom portion
    bottom_portion = gray[height*2//3:, :]
    edges = cv2.Canny(bottom_portion, 50, 150)
    edge_density = np.sum(edges > 0) / (bottom_portion.shape[0] * bottom_portion.shape[1])

    # Footer characteristics: uniform top, some complexity at bottom
    if top_std < 20 and edge_density > 0.01:
        return True

    return False

# %%
def estimate_crop_position(text: str, scan_height: int) -> int:
    """Estimate where to crop based on detected text"""
    # Simple heuristic: crop about 1/3 of scan region if we found footer text
    return min(80, scan_height // 3)

# %%
def try_ocr_detection(footer_region: np.ndarray, scan_height: int, scan_start_y: int) -> Tuple[bool, int, str]:
    """Try OCR-based footer detection with precise positioning"""

    # Preprocess image for better OCR
    preprocessing_methods = [
        ("original", footer_region),
        ("contrast", cv2.convertScaleAbs(cv2.cvtColor(footer_region, cv2.COLOR_BGR2GRAY), alpha=2.0, beta=0)),
        ("threshold", cv2.threshold(cv2.cvtColor(footer_region, cv2.COLOR_BGR2GRAY), 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]),
        ("grayscale", cv2.cvtColor(footer_region, cv2.COLOR_BGR2GRAY)),
    ]

    best_text = ""
    best_method = ""

    for preprocess_name, processed_img in preprocessing_methods:
        # Convert to PIL for tesseract
        if len(processed_img.shape) == 3:
            pil_img = Image.fromarray(cv2.cvtColor(processed_img, cv2.COLOR_BGR2RGB))
        else:
            pil_img = Image.fromarray(processed_img)

        for strategy_name, config in OCR_STRATEGIES:
            try:
                extracted_text = pytesseract.image_to_string(pil_img, config=config)
                extracted_text = extracted_text.strip()

                if len(extracted_text) > len(best_text):
                    best_text = extracted_text
                    best_method = f"{preprocess_name} + {strategy_name}"

                # Check for footer patterns (stricter matching)
                for pattern in FOOTER_TEXT_PATTERNS:
                    if pattern in extracted_text:
                        print(f"  ✅ OCR found pattern '{pattern}' in text: '{extracted_text[:50]}...'")
                        print(f"  🔧 Using method: {preprocess_name} + {strategy_name}")

                        # Try to get precise positioning with bounding boxes
                        crop_pos = get_precise_footer_position(pil_img, config, pattern, scan_height)
                        return True, crop_pos, best_method

            except Exception as e:
                continue

    if best_text:
        print(f"  📝 Best OCR text found: '{best_text[:100]}...'")
        print(f"  ❌ But no footer patterns matched")
    else:
        print(f"  ❌ No readable text found in footer region")

    return False, 0, best_method

# %%
def detect_footer_location(image: np.ndarray, scan_height: int = 150) -> Tuple[bool, int, str]:
    """
    footer detection with correct cropping calculation

    Returns:
        (footer_found: bool, crop_position: int, detection_method: str)
    """
    height, width = image.shape[:2]

    # Define the bottom region to scan
    scan_region_start = max(0, height - scan_height)
    footer_region = image[scan_region_start:height, :]

    print(f"  🔍 Scanning footer region: {width}x{scan_height} pixels")
    print(f"  📍 Scan region: y={scan_region_start} to y={height}")

    # Strategy 1: OCR-based detection with precise cropping
    footer_found, crop_pos, method = try_ocr_detection(footer_region, scan_height, scan_region_start)
    if footer_found:
        print(f"  ✅ OCR detected footer, will crop {crop_pos} pixels from bottom")
        return True, crop_pos, f"OCR: {method}"

    # Strategy 2: Visual pattern detection (more conservative)
    footer_found, crop_pos = try_visual_detection(footer_region, scan_height)
    if footer_found:
        print(f"  👁️ Visual detected footer, will crop {crop_pos} pixels from bottom")
        return True, crop_pos, "Visual pattern"

    print(f"  ❌ No footer detected - using minimal crop")
    return False, 30, "None"  # Minimal fallback crop

# %%
def get_precise_footer_position(pil_img: Image, config: str, found_pattern: str, scan_height: int) -> int:
    """Get precise footer position using OCR bounding boxes"""
    try:
        # Get detailed OCR data with bounding boxes
        data = pytesseract.image_to_data(pil_img, config=config, output_type=pytesseract.Output.DICT)

        # Find text that contains our pattern
        min_y = scan_height  # Start from bottom of scan region

        for i, text in enumerate(data['text']):
            if text.strip() and int(data['conf'][i]) > 30:  # Confidence threshold
                if found_pattern in text or any(part in text for part in found_pattern.split()):
                    y_position = int(data['top'][i])
                    min_y = min(min_y, y_position)
                    print(f"    📍 Found footer text '{text}' at y={y_position}")

        if min_y < scan_height:
            # Add padding above the footer text
            crop_position = scan_height - min_y + 20  # 20px padding above text
            print(f"    📏 Calculated crop position: {crop_position} pixels from bottom")
            return max(50, min(crop_position, scan_height - 20))  # Ensure reasonable bounds
        else:
            print(f"    ⚠️ Could not locate footer text precisely, using default")
            return 80  # Default footer crop

    except Exception as e:
        print(f"    ⚠️ Precise positioning failed: {e}")
        return 80  # Default footer crop

# %%
def crop_margins(image: np.ndarray, top: int, left: int, right: int,
                      auto_footer: bool = True, scan_height: int = 150) -> Tuple[np.ndarray, Dict]:
    """
    smart crop with detailed debug output
    """
    height, width = image.shape[:2]
    print(f"  📐 Input image size: {width}x{height}")

    # Top and side margins
    y_start = min(top, height // 4)
    x_start = min(left, width // 4)
    x_end = max(width - right, width * 3 // 4)

    print(f"  ✂️ Side/top crops: left={x_start}, right={width-x_end}, top={y_start}")

    # Bottom margin with smart footer detection
    if auto_footer:
        footer_found, bottom_crop, method = detect_footer_location(image, scan_height)
    else:
        footer_found = False
        bottom_crop = MANUAL_BOTTOM_MARGIN
        method = "Manual"

    y_end = height - bottom_crop

    print(f"  📏 Bottom crop: {bottom_crop} pixels (method: {method})")
    print(f"  📏 Final crop coordinates: x={x_start}:{x_end}, y={y_start}:{y_end}")

    # Ensure valid coordinates
    y_start = max(0, y_start)
    y_end = min(height, max(y_end, height * 3 // 4))  # Don't crop more than 1/4
    x_start = max(0, x_start)
    x_end = min(width, max(x_end, width * 3 // 4))

    if y_end <= y_start or x_end <= x_start:
        print("  ⚠️ Warning: Invalid crop coordinates, returning original image")
        return image, {'error': 'Invalid crop coordinates'}

    cropped = image[y_start:y_end, x_start:x_end]
    final_height, final_width = cropped.shape[:2]

    print(f"  ✅ Final size: {final_width}x{final_height}")
    print(f"  📊 Cropped: {width-final_width}x{height-final_height} pixels total")

    crop_info = {
        'footer_detected': footer_found,
        'detection_method': method,
        'top_cropped': y_start,
        'bottom_cropped': bottom_crop,
        'left_cropped': x_start,
        'right_cropped': width - x_end,
        'original_size': (width, height),
        'cropped_size': (final_width, final_height)
    }

    return cropped, crop_info

# %%
def process_single_ad(image_info: Dict, output_dir: str) -> Dict:
    """Process a single ad page with smart footer detection"""
    issue = image_info['issue']
    page_num = image_info['page_num']
    filename = image_info['filename']
    input_path = image_info['full_path']

    print(f"\n📄 Processing Issue {issue}, Page {page_num} ({filename})")

    try:
        # Read image
        image = cv2.imread(input_path)
        if image is None:
            print(f"❌ Could not load image: {input_path}")
            return {'success': False, 'error': 'Could not load image'}

        original_height, original_width = image.shape[:2]
        print(f"  📐 Original size: {original_width}x{original_height}")

        # Smart crop margins if enabled
        crop_info = {}
        if CROP_MARGINS:
            image, crop_info = crop_margins(
                image, TOP_MARGIN, LEFT_MARGIN, RIGHT_MARGIN,
                AUTO_DETECT_FOOTER, FOOTER_SCAN_HEIGHT
            )

            if 'error' in crop_info:
                print(f"  ❌ Cropping failed: {crop_info['error']}")
                return {'success': False, 'error': crop_info['error']}

            new_height, new_width = image.shape[:2]
            print(f"  ✂️  After smart cropping: {new_width}x{new_height}")
            if crop_info.get('footer_detected', False):
                print(f"  📄 Footer auto-detected and removed")
            else:
                print(f"  📄 No footer detected, minimal bottom crop applied")
        else:
            new_height, new_width = original_height, original_width
            crop_info = {'footer_detected': False}

        # Check minimum size
        if new_width < MIN_IMAGE_SIZE[0] or new_height < MIN_IMAGE_SIZE[1]:
            print(f"⚠️  Warning: Image too small after cropping ({new_width}x{new_height})")

        # Create output filename
        output_filename = f"issue_{issue}_page_{page_num}_single_ad.jpg"
        output_path = os.path.join(output_dir, output_filename)

        # Save processed image
        success = cv2.imwrite(output_path, image, [cv2.IMWRITE_JPEG_QUALITY, JPEG_QUALITY])

        if success:
            print(f"  ✅ Saved: {output_filename}")
            result = {
                'success': True,
                'issue': issue,
                'page_num': page_num,
                'original_filename': filename,
                'output_filename': output_filename,
                'output_path': output_path,
                'original_size': (original_width, original_height),
                'final_size': (new_width, new_height),
                'cropped': CROP_MARGINS,
                'footer_detected': crop_info.get('footer_detected', False),
                'crop_details': crop_info
            }
        else:
            print(f"❌ Failed to save image")
            result = {'success': False, 'error': 'Failed to save image'}

        return result

    except Exception as e:
        print(f"❌ Error processing image: {e}")
        return {'success': False, 'error': str(e)}

# %%
print("🔍 Discovering single ad images...")
single_ad_images = get_single_ad_images(SINGLE_AD_INPUT)

if single_ad_images:
    print(f"\n📋 FOUND {len(single_ad_images)} SINGLE AD IMAGES:")
    print("="*50)

    current_issue = None
    for img in single_ad_images:
        if img['issue'] != current_issue:
            current_issue = img['issue']
            print(f"\n📖 Issue {current_issue}:")
        print(f"  - Page {img['page_num']}: {img['filename']}")
else:
    print("❌ No single ad images found. Check your folder structure!")
# Out:
# Streaming output truncated to the last 5000 lines.
#     - Page 122: 122.jpg
#     - Page 123: 123.jpg
#     - Page 125: 125.jpg
#     - Page 126: 126.jpg
#     - Page 127: 127.jpg
#     - Page 129: 129.jpg
#     - Page 131: 131.jpg
#     - Page 153: 153.jpg
#     - Page 157: 157.jpg
#     - Page 159: 159.jpg
#     - Page 160: 160.jpg
#     - Page 161: 161.jpg
#     - Page 162: 162.jpg
#     - Page 163: 163.jpg
#   - Page 81: page_81.jpg
#   - Page 83: page_83.jpg
#   - Page 85: page_85.jpg
#   - Page 88: page_88.jpg
#   - Page 89: page_89.jpg
#   - Page 91: page_91.jpg
#   - Page 96: page_96.jpg
#   - Page 97: page_97.jpg
#   - Page 98: page_98.jpg
#   - Page 99: page_99.jpg
#   - Page 100: page_100.jpg
#   - Page 101: page_101.jpg
#   - Page 102: page_102.jpg
#   - Page 105: page_105.jpg
#   - Page 106: page_106.jpg
#   - Page 107: page_107.jpg
#   - Page 109: page_109.jpg
#   - Page 111: page_111.jpg
#   - Page 113: page_113.jpg
#   - Page 115: page_115.jpg
#   - Page 117: page_117.jpg
#   - Page 118: page_118.jpg
#   - Page 120: page_120.jpg
#   - Page 121: page_121.jpg
#   - Page 124: page_124.jpg
#   - Page 126: page_126.jpg
#   - Page 127: page_127.jpg
#   - Page 128: page_128.jpg
#   - Page 131: page_131.jpg
#   - Page 134: page_134.jpg
#   - Page 136: page_136.jpg
#   - Page 137: page_137.jpg
#   - Page 140: page_140.jpg
#   - Page 142: page_142.jpg
#   - Page 143: page_143.jpg
#   - Page 144: page_144.jpg
#   - Page 146: page_146.jpg
#   - Page 147: page_147.jpg
#   - Page 149: page_149.jpg
#   - Page 153: page_153.jpg
#   - Page 161: page_161.jpg
#   - Page 163: page_163.jpg
#   - Page 167: page_167.jpg
#   - Page 170: page_170.jpg
#   - Page 171: page_171.jpg
#   - Page 172: page_172.jpg
#   - Page 173: page_173.jpg
#   - Page 174: page_174.jpg
#   - Page 175: page_175.jpg
#   - Page 176: page_176.jpg

# %%
if single_ad_images:
    print(f"\n🚀 Processing {len(single_ad_images)} single ad images...")

    # Create output directory
    os.makedirs(SINGLE_AD_OUTPUT, exist_ok=True)

    # Process each image
    results = {
        'total_processed': 0,
        'successful': 0,
        'failed': 0,
        'details': []
    }

    for image_info in single_ad_images:
        result = process_single_ad(image_info, SINGLE_AD_OUTPUT)
        results['details'].append(result)
        results['total_processed'] += 1

        if result['success']:
            results['successful'] += 1
        else:
            results['failed'] += 1

    # Print summary with footer detection stats
    print(f"\n📊 PROCESSING COMPLETE:")
    print("="*40)
    print(f"Total images processed: {results['total_processed']}")
    print(f"Successful: {results['successful']}")
    print(f"Failed: {results['failed']}")

    if results['successful'] > 0:
        footer_detected_count = sum(1 for detail in results['details']
                                  if detail.get('success', False) and detail.get('footer_detected', False))
        print(f"Footer auto-detected: {footer_detected_count}/{results['successful']}")

    if results['failed'] > 0:
        print(f"\n❌ Failed images:")
        for detail in results['details']:
            if not detail['success']:
                print(f"  - Error: {detail.get('error', 'Unknown error')}")

    # Save results
    results_file = os.path.join(SINGLE_AD_OUTPUT, "processing_results.json")
    with open(results_file, 'w') as f:
        json.dump(results, f, indent=2, default=str)
    print(f"\n💾 Results saved to: {results_file}")

    # Show output directory contents
    if os.path.exists(SINGLE_AD_OUTPUT):
        output_files = [f for f in os.listdir(SINGLE_AD_OUTPUT) if f.endswith('.jpg')]
        print(f"\n📁 Output directory contains {len(output_files)} ad files:")
        for file in sorted(output_files)[:10]:  # Show first 10
            print(f"  - {file}")
        if len(output_files) > 10:
            print(f"  ... and {len(output_files) - 10} more")

else:
    print("❌ No images to process")
# Out:
# Streaming output truncated to the last 5000 lines.
#   🔧 Using method: original + Sparse text Hebrew
#     ⚠️ Could not locate footer text precisely, using default
#   ✅ OCR detected footer, will crop 80 pixels from bottom
#   📏 Bottom crop: 80 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2259
#   ✅ Final size: 1457x2209
#   📊 Cropped: 40x130 pixels total
#   ✂️  After smart cropping: 1457x2209
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_109_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 113 (page_113.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'הר...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.709)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1229_page_113_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 114 (page_114.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '₪3 כּח הפרסום...'
#   🔧 Using method: original + Hebrew + English
#     📍 Found footer text 'הפרסום' at y=38
#     📏 Calculated crop position: 162 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_114_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 115 (page_115.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'כח הפרסום ₪3...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=51
#     📍 Found footer text 'הפרסום' at y=51
#     📏 Calculated crop position: 149 pixels from bottom
#   ✅ OCR detected footer, will crop 149 pixels from bottom
#   📏 Bottom crop: 149 pixels (method: OCR: original + Hebrew only)
#   📏 Final crop coordinates: x=20:1477, y=50:2190
#   ✅ Final size: 1457x2140
#   📊 Cropped: 40x199 pixels total
#   ✂️  After smart cropping: 1457x2140
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_115_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 117 (page_117.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: 'כּח הפרסום ₪...'
#   🔧 Using method: original + Hebrew + English
#     ⚠️ Could not locate footer text precisely, using default
#   ✅ OCR detected footer, will crop 80 pixels from bottom
#   📏 Bottom crop: 80 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2259
#   ✅ Final size: 1457x2209
#   📊 Cropped: 40x130 pixels total
#   ✂️  After smart cropping: 1457x2209
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_117_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 118 (page_118.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'ב ו הור תווחו...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.000)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1229_page_118_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 119 (page_119.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '- - ד -
#
# ₪
#
# כּח הפרסום ₪...'
#   🔧 Using method: original + Sparse text Hebrew
#     📍 Found footer text 'הפרסום' at y=40
#     📏 Calculated crop position: 160 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: original + Single text line Hebrew)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_119_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 121 (page_121.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: '.2 הרע /\
#
# "שוייי ויוי יו
#
# ויו ולי
#
# 7יין | - אייי .ו וני יי
#
# וי 2
#
# 0.
#
# וש
#
# מודיעין עילית: נתיבות המש...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: Found text patterns (dark ratio: 0.044)
#   👁️ Visual detected footer, will crop 75 pixels from bottom
#   📏 Bottom crop: 75 pixels (method: Visual pattern)
#   📏 Final crop coordinates: x=20:1477, y=50:2264
#   ✅ Final size: 1457x2214
#   📊 Cropped: 40x125 pixels total
#   ✂️  After smart cropping: 1457x2214
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_121_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 123 (page_123.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: 'כּח הפרסום ₪3...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'הפרסום' at y=55
#     📏 Calculated crop position: 145 pixels from bottom
#   ✅ OCR detected footer, will crop 145 pixels from bottom
#   📏 Bottom crop: 145 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2194
#   ✅ Final size: 1457x2144
#   📊 Cropped: 40x195 pixels total
#   ✂️  After smart cropping: 1457x2144
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_123_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 125 (page_125.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'כח הפרסום ₪...'
#   🔧 Using method: original + Sparse text Hebrew
#     📍 Found footer text 'כח' at y=19
#     📍 Found footer text 'הפרסום' at y=37
#     📏 Calculated crop position: 181 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: original + Sparse text Hebrew)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_125_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 126 (page_126.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '₪3 כּח הפרסום...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'הפרסום' at y=42
#     📏 Calculated crop position: 158 pixels from bottom
#   ✅ OCR detected footer, will crop 158 pixels from bottom
#   📏 Bottom crop: 158 pixels (method: OCR: original + Hebrew only)
#   📏 Final crop coordinates: x=20:1477, y=50:2181
#   ✅ Final size: 1457x2131
#   📊 Cropped: 40x208 pixels total
#   ✂️  After smart cropping: 1457x2131
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_126_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 127 (page_127.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: 'ל כ הפרסום ‏ ₪...'
#   🔧 Using method: original + Hebrew + English
#     📍 Found footer text 'הפרסום ‏' at y=20
#     📏 Calculated crop position: 180 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_127_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 128 (page_128.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: ':
# ₪3 כח הפרסום...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=67
#     📍 Found footer text 'הפרסום' at y=67
#     📏 Calculated crop position: 133 pixels from bottom
#   ✅ OCR detected footer, will crop 133 pixels from bottom
#   📏 Bottom crop: 133 pixels (method: OCR: original + Sparse text Hebrew)
#   📏 Final crop coordinates: x=20:1477, y=50:2206
#   ✅ Final size: 1457x2156
#   📊 Cropped: 40x183 pixels total
#   ✂️  After smart cropping: 1457x2156
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_128_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 129 (page_129.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: '|
# הכח הפרסום ₪...'
#   🔧 Using method: original + Hebrew + English
#     📍 Found footer text 'הכח' at y=53
#     📍 Found footer text 'הפרסום' at y=53
#     📏 Calculated crop position: 147 pixels from bottom
#   ✅ OCR detected footer, will crop 147 pixels from bottom
#   📏 Bottom crop: 147 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2192
#   ✅ Final size: 1457x2142
#   📊 Cropped: 40x197 pixels total
#   ✂️  After smart cropping: 1457x2142
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_129_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 131 (page_131.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: '+ּנ9י"-...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.999)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1229_page_131_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 138 (page_138.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '‎na FE‏ הפרסום
# ‎ae‏ =...'
#   🔧 Using method: original + Hebrew + English
#     📍 Found footer text 'הפרסום' at y=18
#     📏 Calculated crop position: 182 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_138_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 139 (page_139.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'כח הפרסום 53...'
#   🔧 Using method: contrast + Hebrew only
#     📍 Found footer text 'כח' at y=42
#     📍 Found footer text 'הפרסום' at y=42
#     📏 Calculated crop position: 158 pixels from bottom
#   ✅ OCR detected footer, will crop 158 pixels from bottom
#   📏 Bottom crop: 158 pixels (method: OCR: contrast + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2181
#   ✅ Final size: 1457x2131
#   📊 Cropped: 40x208 pixels total
#   ✂️  After smart cropping: 1457x2131
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_139_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 141 (page_141.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'כח הפרסום ₪...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=41
#     📍 Found footer text 'הפרסום' at y=40
#     📏 Calculated crop position: 160 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: contrast + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_141_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 147 (page_147.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '. ות כּח הפרסום ₪...'
#   🔧 Using method: original + Single text line Hebrew
#     📍 Found footer text 'הפרסום' at y=25
#     📏 Calculated crop position: 175 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: original + Single text line Hebrew)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_147_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 151 (page_151.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'כח הפרסום =...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=42
#     📍 Found footer text 'הפרסום' at y=42
#     📏 Calculated crop position: 158 pixels from bottom
#   ✅ OCR detected footer, will crop 158 pixels from bottom
#   📏 Bottom crop: 158 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2181
#   ✅ Final size: 1457x2131
#   📊 Cropped: 40x208 pixels total
#   ✂️  After smart cropping: 1457x2131
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_151_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 153 (page_153.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: '--- = כח הפרסום ₪...'
#   🔧 Using method: original + Single text line Hebrew
#     📍 Found footer text 'כח' at y=51
#     📍 Found footer text 'הפרסום' at y=42
#     📏 Calculated crop position: 158 pixels from bottom
#   ✅ OCR detected footer, will crop 158 pixels from bottom
#   📏 Bottom crop: 158 pixels (method: OCR: original + Single text line Hebrew)
#   📏 Final crop coordinates: x=20:1477, y=50:2181
#   ✅ Final size: 1457x2131
#   📊 Cropped: 40x208 pixels total
#   ✂️  After smart cropping: 1457x2131
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_153_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 154 (page_154.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: '₪)כח הפרסום...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'הפרסום' at y=33
#     📏 Calculated crop position: 167 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_154_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 155 (page_155.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '‎ree EN‏ רכומ וס מ ו
# כּח הפרסום ₪...'
#   🔧 Using method: original + Hebrew + English
#     📍 Found footer text 'הפרסום' at y=83
#     📏 Calculated crop position: 117 pixels from bottom
#   ✅ OCR detected footer, will crop 117 pixels from bottom
#   📏 Bottom crop: 117 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2222
#   ✅ Final size: 1457x2172
#   📊 Cropped: 40x167 pixels total
#   ✂️  After smart cropping: 1457x2172
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_155_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 156 (page_156.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'וני יו רו של ן עוכן ?וו ברו ב-קורורו. קלר נה
#
# מומחים
#
# ב
#
# |  ר‎
#
# הנאה משליפה אוטומטית של תרגילי הכפל,...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.006)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1229_page_156_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 157 (page_157.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'א
#
# -
#
# ו ה \
#
# -
#
# --
#
# ו
#
# -
#
# 2 .= ו
#
# וו
#
# וו \...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.999)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1229_page_157_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 158 (page_158.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'כח הפרסום...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=55
#     📍 Found footer text 'הפרסום' at y=62
#     📏 Calculated crop position: 145 pixels from bottom
#   ✅ OCR detected footer, will crop 145 pixels from bottom
#   📏 Bottom crop: 145 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2194
#   ✅ Final size: 1457x2144
#   📊 Cropped: 40x195 pixels total
#   ✂️  After smart cropping: 1457x2144
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_158_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 159 (page_159.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: 'האמ כרז הפרסום כ...'
#   🔧 Using method: original + Hebrew only
#     ⚠️ Could not locate footer text precisely, using default
#   ✅ OCR detected footer, will crop 80 pixels from bottom
#   📏 Bottom crop: 80 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2259
#   ✅ Final size: 1457x2209
#   📊 Cropped: 40x130 pixels total
#   ✂️  After smart cropping: 1457x2209
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1229_page_159_single_ad.jpg
#
# 📄 Processing Issue 1229, Page 160 (page_160.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'מ וכל
#
# הווה
#
# מבינים בבשור
#
# אי ברק בלבד
#
# ביב: רח שדמה המלך 17 | מעשלוחים והזמנות: 0-90ל-03-570 8
#
# ירו...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.923)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1229_page_160_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 3 (page_03.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'בי - שו =
#
# מול האודיטוריום וקו 8
#
# 1
#
# 4-ל
#
# ברוקם
#
# לאורטופד ד"ר אבי ויםנון נא לתזום טלפונית...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.999)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1230_page_3_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 5 (page_05.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: '‎ww oe - 2 % 0 / /‏
# ‎tn 18‏ עו ענה לפונ ה ה 00 22 8 > בי טק | ום ו 1000 2-0 | א | לה זט שר נועבו לצו...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.271)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1230_page_5_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 6 (page_06.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: '+י+ תת תתת- ‎ '1‏ עעעתא ע/,.]/]][]||]ָ...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.000)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1230_page_6_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 7 (page_07.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'ב מגה 6 776 ד ג ,ג ד בג ‎a‏
# ‏כח הפרסום ₪...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=67
#     📍 Found footer text 'הפרסום' at y=67
#     📏 Calculated crop position: 133 pixels from bottom
#   ✅ OCR detected footer, will crop 133 pixels from bottom
#   📏 Bottom crop: 133 pixels (method: OCR: contrast + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2206
#   ✅ Final size: 1457x2156
#   📊 Cropped: 40x183 pixels total
#   ✂️  After smart cropping: 1457x2156
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_7_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 8 (page_08.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '‎ —‏ וו .ירי
# 8 כּח הפרסום...'
#   🔧 Using method: original + Hebrew + English
#     ⚠️ Could not locate footer text precisely, using default
#   ✅ OCR detected footer, will crop 80 pixels from bottom
#   📏 Bottom crop: 80 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2259
#   ✅ Final size: 1457x2209
#   📊 Cropped: 40x130 pixels total
#   ✂️  After smart cropping: 1457x2209
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_8_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 9 (page_09.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: '| 095-/602060 =...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.999)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1230_page_9_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 10 (page_10.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '₪ כפח הפרסום
# ו...'
#   🔧 Using method: original + Hebrew + English
#     📍 Found footer text 'הפרסום' at y=72
#     📏 Calculated crop position: 128 pixels from bottom
#   ✅ OCR detected footer, will crop 128 pixels from bottom
#   📏 Bottom crop: 128 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2211
#   ✅ Final size: 1457x2161
#   📊 Cropped: 40x178 pixels total
#   ✂️  After smart cropping: 1457x2161
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_10_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 11 (page_11.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '0000000000 ‏8-ו‎ OD COH
# ₪ ‏כף הפרסום‎ =...'
#   🔧 Using method: original + Hebrew + English
#     📍 Found footer text 'הפרסום‎' at y=57
#     📏 Calculated crop position: 143 pixels from bottom
#   ✅ OCR detected footer, will crop 143 pixels from bottom
#   📏 Bottom crop: 143 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2196
#   ✅ Final size: 1457x2146
#   📊 Cropped: 40x193 pixels total
#   ✂️  After smart cropping: 1457x2146
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_11_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 13 (page_13.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: '= כח הפרסום ב...'
#   🔧 Using method: original + Sparse text Hebrew
#     📍 Found footer text 'כח' at y=58
#     📍 Found footer text 'הפרסום' at y=58
#     📏 Calculated crop position: 142 pixels from bottom
#   ✅ OCR detected footer, will crop 142 pixels from bottom
#   📏 Bottom crop: 142 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2197
#   ✅ Final size: 1457x2147
#   📊 Cropped: 40x192 pixels total
#   ✂️  After smart cropping: 1457x2147
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_13_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 15 (page_15.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: 'חההחחה
# = כ הפרסום 3...'
#   🔧 Using method: original + Hebrew only
#     📍 Found footer text 'הפרסום' at y=51
#     📏 Calculated crop position: 149 pixels from bottom
#   ✅ OCR detected footer, will crop 149 pixels from bottom
#   📏 Bottom crop: 149 pixels (method: OCR: original + Hebrew only)
#   📏 Final crop coordinates: x=20:1477, y=50:2190
#   ✅ Final size: 1457x2140
#   📊 Cropped: 40x199 pixels total
#   ✂️  After smart cropping: 1457x2140
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_15_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 16 (page_16.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '₪ כּח הפרסום...'
#   🔧 Using method: original + Hebrew + English
#     📍 Found footer text 'הפרסום' at y=39
#     📏 Calculated crop position: 161 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_16_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 17 (page_17.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '| דנ
# כּח הפרסום ₪...'
#   🔧 Using method: original + Hebrew + English
#     📍 Found footer text 'הפרסום' at y=74
#     📏 Calculated crop position: 126 pixels from bottom
#   ✅ OCR detected footer, will crop 126 pixels from bottom
#   📏 Bottom crop: 126 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2213
#   ✅ Final size: 1457x2163
#   📊 Cropped: 40x176 pixels total
#   ✂️  After smart cropping: 1457x2163
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_17_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 18 (page_18.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: '3 כח הפרסום...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=67
#     📍 Found footer text 'הפרסום' at y=71
#     📏 Calculated crop position: 133 pixels from bottom
#   ✅ OCR detected footer, will crop 133 pixels from bottom
#   📏 Bottom crop: 133 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2206
#   ✅ Final size: 1457x2156
#   📊 Cropped: 40x183 pixels total
#   ✂️  After smart cropping: 1457x2156
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_18_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 19 (page_19.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: 'זהגרזות עווות, טיבים ומבצעים עקגי אחרינו: <> 51-16...'
#   🔧 Using method: contrast + Single text line Hebrew
#     📍 Found footer text 'הפרסום' at y=76
#     📏 Calculated crop position: 124 pixels from bottom
#   ✅ OCR detected footer, will crop 124 pixels from bottom
#   📏 Bottom crop: 124 pixels (method: OCR: contrast + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2215
#   ✅ Final size: 1457x2165
#   📊 Cropped: 40x174 pixels total
#   ✂️  After smart cropping: 1457x2165
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_19_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 20 (page_20.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: '₪1 כח הפרסום...'
#   🔧 Using method: original + Sparse text Hebrew
#     📍 Found footer text 'כח' at y=69
#     📍 Found footer text 'הפרסום' at y=73
#     📏 Calculated crop position: 131 pixels from bottom
#   ✅ OCR detected footer, will crop 131 pixels from bottom
#   📏 Bottom crop: 131 pixels (method: OCR: original + Sparse text Hebrew)
#   📏 Final crop coordinates: x=20:1477, y=50:2208
#   ✅ Final size: 1457x2158
#   📊 Cropped: 40x181 pixels total
#   ✂️  After smart cropping: 1457x2158
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_20_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 21 (page_21.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: 'שעות פתיחה: ימים א' ב' דד ה' 10:30-10:30 ג' 10:30-...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'הפרסום' at y=76
#     📍 Found footer text 'הפרסום' at y=106
#     📏 Calculated crop position: 124 pixels from bottom
#   ✅ OCR detected footer, will crop 124 pixels from bottom
#   📏 Bottom crop: 124 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2215
#   ✅ Final size: 1457x2165
#   📊 Cropped: 40x174 pixels total
#   ✂️  After smart cropping: 1457x2165
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_21_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 22 (page_22.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: 'בואו לרכוב, ליהנות ולהתרענן בבין הזמנים!
#
# מ
#
# ב₪3 כ...'
#   🔧 Using method: original + Sparse text Hebrew
#     📍 Found footer text 'הפרסום' at y=89
#     📏 Calculated crop position: 111 pixels from bottom
#   ✅ OCR detected footer, will crop 111 pixels from bottom
#   📏 Bottom crop: 111 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2228
#   ✅ Final size: 1457x2178
#   📊 Cropped: 40x161 pixels total
#   ✂️  After smart cropping: 1457x2178
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_22_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 23 (page_23.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: '‎yi 1‏ 4-%\! 0(%! ו ו 2+ + ‎ft‏ .£24 14.2% "שר א |
# כח הפרםום ה...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.000)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1230_page_23_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 24 (page_24.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: '99:00-14:00 ‏שעות פתיחה: 10:00-21:00יום ו' 9:00-13:00 שעות פתיחה: 9:00-21:00 יום ו'‎ UP Spe
# ‏הח ההרח...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.003)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1230_page_24_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 25 (page_25.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: '₪.
#
# לקביעת ראיון: בתאל: 053-4100808
#
# מובילים בעולם התעסוקה...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.539)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1230_page_25_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 27 (page_27.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '= בח הפרסום (1)...'
#   🔧 Using method: original + Hebrew only
#     📍 Found footer text 'הפרסום' at y=61
#     📏 Calculated crop position: 139 pixels from bottom
#   ✅ OCR detected footer, will crop 139 pixels from bottom
#   📏 Bottom crop: 139 pixels (method: OCR: original + Hebrew only)
#   📏 Final crop coordinates: x=20:1477, y=50:2200
#   ✅ Final size: 1457x2150
#   📊 Cropped: 40x189 pixels total
#   ✂️  After smart cropping: 1457x2150
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_27_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 29 (page_29.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'קייט חק לי ונידי יי ור ו -" וקור יי דריי יי קורי ,רייר ד יושיר ד וויק יוויש ,שווווץ שש...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.999)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1230_page_29_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 30 (page_30.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: ',תתה 2 . ת-...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.000)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1230_page_30_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 31 (page_31.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: '0000000 שה...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.000)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1230_page_31_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 33 (page_33.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: 'כּח הפרסום 53...'
#   🔧 Using method: original + Single text line Hebrew
#     📍 Found footer text 'הפרסום' at y=66
#     📏 Calculated crop position: 134 pixels from bottom
#   ✅ OCR detected footer, will crop 134 pixels from bottom
#   📏 Bottom crop: 134 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2205
#   ✅ Final size: 1457x2155
#   📊 Cropped: 40x184 pixels total
#   ✂️  After smart cropping: 1457x2155
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_33_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 34 (page_34.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'ne BIDIBT ND ED...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.000)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1230_page_34_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 35 (page_35.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'כח הפרסום ₪3...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=80
#     📍 Found footer text 'הפרסום' at y=80
#     📏 Calculated crop position: 120 pixels from bottom
#   ✅ OCR detected footer, will crop 120 pixels from bottom
#   📏 Bottom crop: 120 pixels (method: OCR: contrast + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2219
#   ✅ Final size: 1457x2169
#   📊 Cropped: 40x170 pixels total
#   ✂️  After smart cropping: 1457x2169
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_35_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 37 (page_37.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'ו וו ה...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.000)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1230_page_37_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 39 (page_39.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'ו ה ה ה 0...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.000)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1230_page_39_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 42 (page_42.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'ב כח הפרסום...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=27
#     📍 Found footer text 'הפרסום' at y=27
#     📏 Calculated crop position: 173 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_42_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 43 (page_43.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'כח הפרסום ₪3...'
#   🔧 Using method: original + Sparse text Hebrew
#     📍 Found footer text 'כח' at y=0
#     📍 Found footer text 'הפרסום' at y=34
#     📏 Calculated crop position: 200 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: original + Single text line Hebrew)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_43_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 44 (page_44.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '‎na Cy‏ הפרסום
# ‎SS‏...'
#   🔧 Using method: original + Hebrew + English
#     📍 Found footer text 'הפרסום' at y=31
#     📏 Calculated crop position: 169 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_44_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 45 (page_45.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: '\.
# כח הפרסום ₪3...'
#   🔧 Using method: original + Hebrew + English
#     📍 Found footer text 'כח' at y=80
#     📍 Found footer text 'הפרסום' at y=80
#     📏 Calculated crop position: 120 pixels from bottom
#   ✅ OCR detected footer, will crop 120 pixels from bottom
#   📏 Bottom crop: 120 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2219
#   ✅ Final size: 1457x2169
#   📊 Cropped: 40x170 pixels total
#   ✂️  After smart cropping: 1457x2169
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1230_page_45_single_ad.jpg
#
# 📄 Processing Issue 1230, Page 46 (page_46.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
# ...
#   ✅ Saved: issue_1231_page_136_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 137 (page_137.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: 'הי הוור ‎i‏ ו וו
# כ הפרסום ₪...'
#   🔧 Using method: original + Hebrew + English
#     📍 Found footer text 'הפרסום' at y=63
#     📏 Calculated crop position: 137 pixels from bottom
#   ✅ OCR detected footer, will crop 137 pixels from bottom
#   📏 Bottom crop: 137 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2202
#   ✅ Final size: 1457x2152
#   📊 Cropped: 40x187 pixels total
#   ✂️  After smart cropping: 1457x2152
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_137_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 140 (page_140.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '₪0 כּח הפרסום...'
#   🔧 Using method: contrast + Hebrew only
#     📍 Found footer text 'הפרסום' at y=33
#     📏 Calculated crop position: 167 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: contrast + Hebrew only)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_140_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 142 (page_142.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: '₪3 כח הפרסום...'
#   🔧 Using method: contrast + Sparse text Hebrew
#     📍 Found footer text 'כח' at y=75
#     📍 Found footer text 'הפרסום' at y=75
#     📏 Calculated crop position: 125 pixels from bottom
#   ✅ OCR detected footer, will crop 125 pixels from bottom
#   📏 Bottom crop: 125 pixels (method: OCR: contrast + Sparse text Hebrew)
#   📏 Final crop coordinates: x=20:1477, y=50:2214
#   ✅ Final size: 1457x2164
#   📊 Cropped: 40x175 pixels total
#   ✂️  After smart cropping: 1457x2164
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_142_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 143 (page_143.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'כח הפרסום 5...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=74
#     📍 Found footer text 'הפרסום' at y=74
#     📏 Calculated crop position: 126 pixels from bottom
#   ✅ OCR detected footer, will crop 126 pixels from bottom
#   📏 Bottom crop: 126 pixels (method: OCR: original + Hebrew only)
#   📏 Final crop coordinates: x=20:1477, y=50:2213
#   ✅ Final size: 1457x2163
#   📊 Cropped: 40x176 pixels total
#   ✂️  After smart cropping: 1457x2163
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_143_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 144 (page_144.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: '[ הר 0.0000 00000...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.000)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1231_page_144_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 146 (page_146.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: '₪3 כח הפרסום...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=24
#     📍 Found footer text 'הפרסום' at y=24
#     📏 Calculated crop position: 176 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_146_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 147 (page_147.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: '—_—_— —_—
# כח הפרסום ‎(i)‏...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=67
#     📍 Found footer text 'הפרסום' at y=67
#     📏 Calculated crop position: 133 pixels from bottom
#   ✅ OCR detected footer, will crop 133 pixels from bottom
#   📏 Bottom crop: 133 pixels (method: OCR: contrast + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2206
#   ✅ Final size: 1457x2156
#   📊 Cropped: 40x183 pixels total
#   ✂️  After smart cropping: 1457x2156
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_147_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 149 (page_149.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: 'אכה הפרסום כ...'
#   🔧 Using method: original + Hebrew only
#     📍 Found footer text 'הפרסום' at y=56
#     📏 Calculated crop position: 144 pixels from bottom
#   ✅ OCR detected footer, will crop 144 pixels from bottom
#   📏 Bottom crop: 144 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2195
#   ✅ Final size: 1457x2145
#   📊 Cropped: 40x194 pixels total
#   ✂️  After smart cropping: 1457x2145
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_149_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 153 (page_153.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: '-----ששטררר ..... תת = :₪ ₪ 2 ּּ2ּ/---: ₪-₪ש₪ ‏ /נ/[/|- :7...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.000)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1231_page_153_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 161 (page_161.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'וח ירושלים 8| פתוח וצוף: 30-23:00:ו1
#
# שניצל בחחישה טעחים
#
# ₪-=₪ א .\...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.999)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1231_page_161_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 163 (page_163.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'כח הפרסום :₪...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=57
#     📍 Found footer text 'הפרסום' at y=58
#     📏 Calculated crop position: 143 pixels from bottom
#   ✅ OCR detected footer, will crop 143 pixels from bottom
#   📏 Bottom crop: 143 pixels (method: OCR: original + Sparse text Hebrew)
#   📏 Final crop coordinates: x=20:1477, y=50:2196
#   ✅ Final size: 1457x2146
#   📊 Cropped: 40x193 pixels total
#   ✂️  After smart cropping: 1457x2146
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_163_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 167 (page_167.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'וכח הפרסום (₪5...'
#   🔧 Using method: original + Hebrew only
#     📍 Found footer text 'וכח' at y=26
#     📍 Found footer text 'הפרסום' at y=26
#     📏 Calculated crop position: 174 pixels from bottom
#   ✅ OCR detected footer, will crop 160 pixels from bottom
#   📏 Bottom crop: 160 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2179
#   ✅ Final size: 1457x2129
#   📊 Cropped: 40x210 pixels total
#   ✂️  After smart cropping: 1457x2129
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_167_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 170 (page_170.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'ה ₪44 סע שא <>?* |ן] 0 מ"ר ו
# ₪3 כח הפרסום 00...'
#   🔧 Using method: contrast + Hebrew only
#     📍 Found footer text 'הפרסום' at y=65
#     📏 Calculated crop position: 135 pixels from bottom
#   ✅ OCR detected footer, will crop 135 pixels from bottom
#   📏 Bottom crop: 135 pixels (method: OCR: original + Sparse text Hebrew)
#   📏 Final crop coordinates: x=20:1477, y=50:2204
#   ✅ Final size: 1457x2154
#   📊 Cropped: 40x185 pixels total
#   ✂️  After smart cropping: 1457x2154
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_170_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 171 (page_171.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'ורצוי 44.09*שטש.רר
#
# בדורון כות כשס דורו יער הרוי
#
# וצו 4-30
#
# יר
#
# 3-0
#
# -
#
# -.-.
#
# יום וי 40:30-12:30
#
# |
# ...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.999)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1231_page_171_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 172 (page_172.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: '‎wo‏ הרה ה
# מ כח הפרסום...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=45
#     📍 Found footer text 'הפרסום' at y=45
#     📏 Calculated crop position: 155 pixels from bottom
#   ✅ OCR detected footer, will crop 155 pixels from bottom
#   📏 Bottom crop: 155 pixels (method: OCR: contrast + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2184
#   ✅ Final size: 1457x2134
#   📊 Cropped: 40x205 pixels total
#   ✂️  After smart cropping: 1457x2134
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_172_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 173 (page_173.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'ו לדא סיכון זצמיחה נוסלת | בטוח בכד תצב 4-ו וו וו
# עיצוב גבוה לתמיד | פתוון סופי לתצה נמוך ושיעור בכל...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: Found text patterns (dark ratio: 0.022)
#   👁️ Visual detected footer, will crop 75 pixels from bottom
#   📏 Bottom crop: 75 pixels (method: Visual pattern)
#   📏 Final crop coordinates: x=20:1477, y=50:2264
#   ✅ Final size: 1457x2214
#   📊 Cropped: 40x125 pixels total
#   ✂️  After smart cropping: 1457x2214
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_173_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 174 (page_174.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'הפרסום' in text: '₪2 כ הפרסום...'
#   🔧 Using method: original + Hebrew + English
#     📍 Found footer text 'הפרסום' at y=42
#     📏 Calculated crop position: 158 pixels from bottom
#   ✅ OCR detected footer, will crop 158 pixels from bottom
#   📏 Bottom crop: 158 pixels (method: OCR: original + Hebrew + English)
#   📏 Final crop coordinates: x=20:1477, y=50:2181
#   ✅ Final size: 1457x2131
#   📊 Cropped: 40x208 pixels total
#   ✂️  After smart cropping: 1457x2131
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_174_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 175 (page_175.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   ✅ OCR found pattern 'כח הפרסום' in text: 'כח הפרסום @...'
#   🔧 Using method: contrast + Hebrew + English
#     📍 Found footer text 'כח' at y=72
#     📍 Found footer text 'הפרסום' at y=72
#     📏 Calculated crop position: 128 pixels from bottom
#   ✅ OCR detected footer, will crop 128 pixels from bottom
#   📏 Bottom crop: 128 pixels (method: OCR: original + Sparse text Hebrew)
#   📏 Final crop coordinates: x=20:1477, y=50:2211
#   ✅ Final size: 1457x2161
#   📊 Cropped: 40x178 pixels total
#   ✂️  After smart cropping: 1457x2161
#   📄 Footer auto-detected and removed
#   ✅ Saved: issue_1231_page_175_single_ad.jpg
#
# 📄 Processing Issue 1231, Page 176 (page_176.jpg)
#   📐 Original size: 1497x2339
#   📐 Input image size: 1497x2339
#   ✂️ Side/top crops: left=20, right=20, top=50
#   🔍 Scanning footer region: 1497x180 pixels
#   📍 Scan region: y=2159 to y=2339
#   📝 Best OCR text found: 'קיבוץ גלויות 24 ב[' ברק 5 דקות הליכה מגשר קוקה קולה...'
#   ❌ But no footer patterns matched
#   👁️ Visual detection: No footer pattern (dark ratio: 0.990)
#   ❌ No footer detected - using minimal crop
#   📏 Bottom crop: 30 pixels (method: None)
#   📏 Final crop coordinates: x=20:1477, y=50:2309
#   ✅ Final size: 1457x2259
#   📊 Cropped: 40x80 pixels total
#   ✂️  After smart cropping: 1457x2259
#   📄 No footer detected, minimal bottom crop applied
#   ✅ Saved: issue_1231_page_176_single_ad.jpg
#
# 📊 PROCESSING COMPLETE:
# ========================================
# Total images processed: 2907
# Successful: 2907
# Failed: 0
# Footer auto-detected: 2042/2907
#
# 💾 Results saved to: /content/drive/MyDrive/Miki_class/Project/Catalog/processed_ads/single_ads/processing_results.json
#
# 📁 Output directory contains 2907 ad files:
#   - issue_1193_page_101_single_ad.jpg
#   - issue_1193_page_104_single_ad.jpg
#   - issue_1193_page_105_single_ad.jpg
#   - issue_1193_page_10_single_ad.jpg
#   - issue_1193_page_112_single_ad.jpg
#   - issue_1193_page_113_single_ad.jpg
#   - issue_1193_page_115_single_ad.jpg
#   - issue_1193_page_117_single_ad.jpg
#   - issue_1193_page_119_single_ad.jpg
#   - issue_1193_page_11_single_ad.jpg
#   ... and 2897 more
